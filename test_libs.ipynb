# %%
from fuzzywuzzy import fuzz, process

# %%
choices = []
with open("data/lookup_tables/location/city.txt", "r") as f:
    for each in f.readlines():
        choices.append(each.replace("\n",""))

# %%
STOPWORDS = [f.replace("\n","") for f in open("data/corpus/stopwords.txt", "r").readlines()]
STOPWORDS
# Out:
# ['a',
#  'able',
#  'about',
#  'above',
#  'abst',
#  'accordance',
#  'according',
#  'accordingly',
#  'across',
#  'act',
#  'actually',
#  'added',
#  'adj',
#  'affected',
#  'affecting',
#  'affects',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ah',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'announce',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apparently',
#  'approximately',
#  'are',
#  'aren',
#  'arent',
#  'arise',
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'at',
#  'auth',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'begin',
#  'beginning',
#  'beginnings',
#  'begins',
#  'behind',
#  'being',
# ...

# %%
text= "HCM"

# %%
print(choices)
print(text)
# for choice in choices:
print(process.extract(text, choices, scorer=fuzz.token_sort_ratio))
# Out:
# ['Can Tho', 'Da Nang', 'Hai Phong', 'Ha Noi', 'Ho Chi Minh', 'Ba Ria', 'Bac Lieu', 'Bac Giang', 'Bac Ninh', 'Bao Loc', 'Bien Hoa', 'Buon Ma Thuot', 'Ben Tre', 'Ca Mau', 'Cam Pha', 'Cao Lanh', 'Da Lat', 'Dien Bien Phu', 'Dong Ha', 'Dong Hoi', 'Ha Tinh', 'Hai Duong', 'Ha Long', 'Hoa Binh', 'Hoi An', 'Hue', 'Hung Yen', 'Kon Tum', 'Lang Son', 'Lao Cai', 'Long Xuyen', 'Mong Cai', 'My Tho', 'Nam Dinh', 'Ninh Binh', 'Nha Trang', 'Cam Ranh', 'Phan Rang', 'Phan Thiet', 'Phu Ly', 'Pleiku', 'Quang Ngai', 'Quy Nhon', 'Rach Gia', 'Soc Trang', 'Son La', 'Tam Ky', 'Tan An', 'Thai Binh', 'Thai Nguyen', 'Thanh Hoa', 'Tra Vinh', 'Tuy Hoa', 'Tuyen Quang', 'Uong Bi', 'Viet Tri', 'Vinh', 'Vinh Yen', 'Vinh Long', 'Vung Tau', 'Yen Bai']
# HCM
# [('Ca Mau', 44), ('Cam Pha', 40), ('Mong Cai', 36), ('Nam Dinh', 36), ('Cam Ranh', 36)]

# %%
fuzz.token_sort_ratio(each, text)
# Out:
# 29

# %%
process.extract(text, choices)
# Out:
# [('Cam Pha', 60),
#  ('Cam Ranh', 60),
#  ('Ca Mau', 44),
#  ('Ho Chi Minh', 43),
#  ('Hue', 33)]

# %%
max_sc = 0
max_word = ""
for each in choices:
    score = fuzz.token_sort_ratio(each, text)
    if score > max_sc:
        max_sc = score
        max_word = each
        print((max_word,max_sc))
(max_word,max_sc)
# Out:
# ('Can Tho', 20)
# ('Ha Noi', 22)
# ('Ho Chi Minh', 29)
# ('Ca Mau', 44)
# ('Ca Mau', 44)

# %%
import re

# %%
text = "billions vnddd and usd"
match = re.findall("(?i)([v]+[n]+[d]+|[u]+[s]+[d]+|[e]+[u]+[r]+[o]+)", text)
print(match)
# if match is not None:
#     print(match.end())
#     print(match.start())
#     print(text[match.start():match.end()])
# else:
#     print("match not found")
# Out:
# ['vnddd', 'usd']
